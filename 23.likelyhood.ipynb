# %%
import graphlab
import math as math
import numpy as np

# %% [markdown]
# #### Calculate the likelihood of this data. Round your answer to 2 decimal places.

# %%
x  = np.array([2.5,0.3,2.8,0.5])

# %%
true_y = np.array([1,-1,1,1])

# %%
yy = 1/(1+ np.exp(-x))

# %%
yy
# Out:
# array([ 0.92414182,  0.57444252,  0.94267582,  0.62245933])

# %%
prod_yy = 0.92414182*(1-0.57444252)*0.94267582*0.62245933

# %%
prod_yy
# Out:
# 0.23076513830100476

# %% [markdown]
# #### Calculate the derivative of the log likelihood with respect to w1. Round your answer to 2 decimal places.

# %%
y = np.array([1,0,1,1])

# %%
p = y-yy

# %%
yt = np.dot(x.T,p)

# %%
yt
# Out:
# 0.36659072192551606

# %%
from IPython.display import Image
Image(filename='great_job.png')

# %%
graphlab.version
# Out:
# '1.8.4'
